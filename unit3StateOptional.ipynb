# %%
import os,sys,math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import r2_score as r2
# %matplotlib inline
e=math.exp
ln=math.log

plt.style.use("fivethirtyeight")

# %%
state=pd.read_csv('data/statedata.csv')
temp=state.groupby('state.region')['HS.Grad'].mean()

murders=state[state['state.region']=='Northeast'].groupby('state.name')['Murder'].median().sort_values(ascending=True)
# Out:
# state.name
# Rhode Island      2.4
# Maine             2.7
# Connecticut       3.1
# Massachusetts     3.3
# New Hampshire     3.3
# New Jersey        5.2
# Vermont           5.5
# Pennsylvania      6.1
# New York         10.9
# Name: Murder, dtype: float64

# %%
x=state[['Population','Income','Illiteracy','Murder','HS.Grad','Frost','Area']]
y=state['Life.Exp']
x=sm.add_constant(x)

leModel=sm.OLS(y,x).fit()

leModel.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Life.Exp   R-squared:                       0.736
# Model:                            OLS   Adj. R-squared:                  0.692
# Method:                 Least Squares   F-statistic:                     16.74
# Date:                Wed, 14 Feb 2018   Prob (F-statistic):           2.53e-10
# Time:                        18:26:13   Log-Likelihood:                -51.855
# No. Observations:                  50   AIC:                             119.7
# Df Residuals:                      42   BIC:                             135.0
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         70.9432      1.748     40.586      0.000      67.416      74.471
# ...

# %%
x=state[['Murder','HS.Grad','Population','Frost']]
x=sm.add_constant(x)

newModel=sm.OLS(y,x).fit()

yPred=newModel.predict(x)

df=pd.DataFrame({'state':state['state.name'],'yPred':yPred})
predict=df.groupby('state')['yPred'].mean().sort_values(ascending=False)
actual=state.groupby('state.name')['Life.Exp'].mean().sort_values(ascending=False)
dif
# Out:
# Alabama          -0.568881
# Alaska            0.547404
# Arizona           0.864157
# Arkansas         -1.086261
# California        0.085646
# Colorado         -0.956458
# Connecticut      -0.445410
# Delaware          1.066469
# Florida          -0.044605
# Georgia           0.096942
# Hawaii           -1.506831
# Idaho            -0.370107
# Illinois          0.052442
# Indiana           0.021585
# Iowa             -0.163471
# Kansas           -0.676480
# Kentucky         -0.855821
# Louisiana         0.390448
# Maine             1.470954
# Maryland          0.298520
# Massachusetts     0.611054
# Michigan         -0.761066
# Minnesota        -0.694404
# Mississippi       0.915354
# Missouri         -0.583900
# Montana           0.840248
# Nebraska         -0.429677
# Nevada            0.494824
# New Hampshire     0.496356
# New Jersey        0.666121
# New Mexico       -0.288809
# New York          0.079371
# North Carolina    0.076242
# North Dakota     -0.903506
# ...
