# %%
import os,sys,math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn.metrics import r2_score as r2
# %matplotlib inline
e=math.exp

plt.style.use("fivethirtyeight")

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error as mse

cc=pd.read_csv('data/climate_change.csv')

ccTrain=cc[cc.Year<=2006]
ccTest=cc[cc.Year>2006]

xTrain=ccTrain.loc[:,'MEI':'Aerosols']
yTrain=ccTrain['Temp']
xTrain=sm.add_constant(xTrain)

xTest=ccTest.loc[:,"MEI":'Aerosols']
yTest=ccTest['Temp']
xTest=sm.add_constant(xTest)

model=sm.OLS(yTrain,xTrain).fit()

yPred=model.predict(xTest)

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   Temp   R-squared:                       0.751
# Model:                            OLS   Adj. R-squared:                  0.744
# Method:                 Least Squares   F-statistic:                     103.6
# Date:                Tue, 13 Feb 2018   Prob (F-statistic):           1.94e-78
# Time:                        11:59:27   Log-Likelihood:                 280.10
# No. Observations:                 284   AIC:                            -542.2
# Df Residuals:                     275   BIC:                            -509.4
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -124.5943     19.887     -6.265      0.000    -163.744     -85.445
# ...

# %%
ccTrain.corrwith(ccTrain['CFC-11'])>0.7
# Out:
# Year        False
# Month       False
# MEI         False
# CO2         False
# CH4          True
# N2O         False
# CFC-11       True
# CFC-12       True
# TSI         False
# Aerosols    False
# Temp        False
# dtype: bool

# %%
ccTrain=ccTrain[['MEI','TSI','Aerosols','N2O','Temp']]

xTrain=ccTrain[['MEI','TSI','N2O','Aerosols']]
yTrain=ccTrain['Temp']
xTrain=sm.add_constant(xTrain)

model=sm.OLS(yTrain,xTrain).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   Temp   R-squared:                       0.726
# Model:                            OLS   Adj. R-squared:                  0.722
# Method:                 Least Squares   F-statistic:                     184.9
# Date:                Tue, 13 Feb 2018   Prob (F-statistic):           3.52e-77
# Time:                        11:59:46   Log-Likelihood:                 266.64
# No. Observations:                 284   AIC:                            -523.3
# Df Residuals:                     279   BIC:                            -505.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       -116.2269     20.223     -5.747      0.000    -156.036     -76.418
# ...
